# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Deliverable 1.3
# Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Deliverable 1.4
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each lat/lng combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# Deliverable 1.5
# Import the API key
from config import weather_api_key

# Import the requests library
import requests

# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Deliverable 1.6
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval.    ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = str(city_weather['weather'][0]['description'])
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Weather Description': city_desc,
                          'Country': city_country,
                          'Date': city_date})

    #If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate that Data Loading is complete.
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval.
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | lasa
# Processing Record 6 of Set 1 | aljezur
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | mbaiki
# Processing Record 15 of Set 1 | foam lake
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | brae
# Processing Record 28 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | verkhoturye
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | camopi
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | uyemskiy
# Processing Record 36 of Set 1 | glenwood springs
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | lancaster
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | nouadhibou
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | nabire
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | bera
# Processing Record 46 of Set 1 | troitsko-pechorsk
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | bud
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | nome
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | hokitika
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | khandbari
# Processing Record 8 of Set 2 | brownsville
# Processing Record 9 of Set 2 | haines junction
# Processing Record 10 of Set 2 | ostersund
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | avera
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | salym
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | aitape
# Processing Record 19 of Set 2 | lixourion
# Processing Record 20 of Set 2 | port arthur
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | mvuma
# Processing Record 23 of Set 2 | padang
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | sao joao da barra
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | flinders
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | tiverton
# Processing Record 31 of Set 2 | challapata
# Processing Record 32 of Set 2 | adet
# Processing Record 33 of Set 2 | yaan
# Processing Record 34 of Set 2 | sur
# Processing Record 35 of Set 2 | kano
# Processing Record 36 of Set 2 | fort saint james
# Processing Record 37 of Set 2 | yenagoa
# Processing Record 38 of Set 2 | egvekinot
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | saint-francois
# Processing Record 41 of Set 2 | nyeri
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | ancud
# Processing Record 45 of Set 2 | barcelos
# Processing Record 46 of Set 2 | tilichiki
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | cah ab
# City not found. Skipping...
# Processing Record 49 of Set 2 | shchuchye
# City not found. Skipping...
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | nishihara
# Processing Record 2 of Set 3 | cayenne
# Processing Record 3 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 3 | uttarkashi
# Processing Record 5 of Set 3 | minot
# Processing Record 6 of Set 3 | san patricio
# Processing Record 7 of Set 3 | lieksa
# Processing Record 8 of Set 3 | talnakh
# Processing Record 9 of Set 3 | labuhan
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | inhambane
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | saint-leu
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | chisec
# Processing Record 16 of Set 3 | kaberamaido
# Processing Record 17 of Set 3 | kysyl-syr
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | coro
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | yanggu
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | provideniya
# Processing Record 24 of Set 3 | husavik
# Processing Record 25 of Set 3 | wakkanai
# Processing Record 26 of Set 3 | chokwe
# Processing Record 27 of Set 3 | puerto colombia
# Processing Record 28 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 3 | manggar
# Processing Record 30 of Set 3 | bella vista
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | varhaug
# Processing Record 34 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 3 | harindanga
# Processing Record 36 of Set 3 | tabou
# Processing Record 37 of Set 3 | tha mai
# Processing Record 38 of Set 3 | lulea
# Processing Record 39 of Set 3 | prado
# Processing Record 40 of Set 3 | les herbiers
# Processing Record 41 of Set 3 | mercedes
# Processing Record 42 of Set 3 | banjarmasin
# Processing Record 43 of Set 3 | paramonga
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 3 | nuuk
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | tiznit
# Processing Record 49 of Set 3 | boyabat
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | sarangani
# Processing Record 3 of Set 4 | vilyuysk
# Processing Record 4 of Set 4 | yar-sale
# Processing Record 5 of Set 4 | suez
# Processing Record 6 of Set 4 | abu samrah
# Processing Record 7 of Set 4 | marsa matruh
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | canico
# Processing Record 11 of Set 4 | tasiilaq
# Processing Record 12 of Set 4 | isla vista
# Processing Record 13 of Set 4 | metehara
# City not found. Skipping...
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | pontes e lacerda
# Processing Record 16 of Set 4 | marsabit
# Processing Record 17 of Set 4 | fortuna
# Processing Record 18 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 4 | norman wells
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | ullapool
# Processing Record 22 of Set 4 | paita
# Processing Record 23 of Set 4 | lompoc
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | maridi
# Processing Record 28 of Set 4 | pangoa
# Processing Record 29 of Set 4 | sao jose da coroa grande
# Processing Record 30 of Set 4 | wewak
# Processing Record 31 of Set 4 | tagudin
# Processing Record 32 of Set 4 | pavlodar
# Processing Record 33 of Set 4 | aklavik
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | mackay
# Processing Record 37 of Set 4 | port lavaca
# Processing Record 38 of Set 4 | hay river
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 4 | aksaray
# Processing Record 42 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 43 of Set 4 | omsukchan
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | urengoy
# Processing Record 46 of Set 4 | santa isabel
# Processing Record 47 of Set 4 | peniche
# Processing Record 48 of Set 4 | ayan
# Processing Record 49 of Set 4 | saint-georges
# Processing Record 50 of Set 4 | watsa
# Processing Record 1 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 5 | kansanshi
# Processing Record 3 of Set 5 | gat
# Processing Record 4 of Set 5 | caravelas
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | terney
# Processing Record 7 of Set 5 | kaohsiung
# Processing Record 8 of Set 5 | sabzevar
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | qaanaaq
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | andra
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | klaksvik
# Processing Record 15 of Set 5 | ballitoville
# Processing Record 16 of Set 5 | hargeysa
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | lavrentiya
# Processing Record 19 of Set 5 | ketchikan
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | great falls
# Processing Record 22 of Set 5 | upington
# Processing Record 23 of Set 5 | airai
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | russell
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | novyy urengoy
# Processing Record 29 of Set 5 | planaltina
# Processing Record 30 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 31 of Set 5 | kaluga
# Processing Record 32 of Set 5 | korcula
# Processing Record 33 of Set 5 | lekoni
# Processing Record 34 of Set 5 | bredasdorp
# Processing Record 35 of Set 5 | mujiayingzi
# Processing Record 36 of Set 5 | mokhsogollokh
# Processing Record 37 of Set 5 | salalah
# Processing Record 38 of Set 5 | cockburn town
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | sidney
# Processing Record 44 of Set 5 | tigil
# Processing Record 45 of Set 5 | linqiong
# Processing Record 46 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 5 | atar
# Processing Record 48 of Set 5 | agadir
# Processing Record 49 of Set 5 | krasnyye baki
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | lata
# Processing Record 2 of Set 6 | nioro
# Processing Record 3 of Set 6 | king city
# Processing Record 4 of Set 6 | la palma
# Processing Record 5 of Set 6 | ca mau
# Processing Record 6 of Set 6 | rundu
# Processing Record 7 of Set 6 | baghdad
# Processing Record 8 of Set 6 | tazovskiy
# Processing Record 9 of Set 6 | san policarpo
# Processing Record 10 of Set 6 | axim
# Processing Record 11 of Set 6 | sumenep
# Processing Record 12 of Set 6 | taoudenni
# Processing Record 13 of Set 6 | hanstholm
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | vila velha
# Processing Record 16 of Set 6 | tessalit
# Processing Record 17 of Set 6 | sesvete
# Processing Record 18 of Set 6 | lubao
# Processing Record 19 of Set 6 | mogadishu
# Processing Record 20 of Set 6 | ambanja
# Processing Record 21 of Set 6 | voyvozh
# Processing Record 22 of Set 6 | trelew
# Processing Record 23 of Set 6 | talcahuano
# Processing Record 24 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | korla
# Processing Record 27 of Set 6 | santiago del estero
# Processing Record 28 of Set 6 | kieta
# Processing Record 29 of Set 6 | adre
# Processing Record 30 of Set 6 | juliaca
# Processing Record 31 of Set 6 | puro
# Processing Record 32 of Set 6 | roald
# Processing Record 33 of Set 6 | usmajac
# Processing Record 34 of Set 6 | emerald
# Processing Record 35 of Set 6 | marsh harbour
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | perbaungan
# Processing Record 38 of Set 6 | sinnamary
# Processing Record 39 of Set 6 | saskylakh
# Processing Record 40 of Set 6 | fare
# Processing Record 41 of Set 6 | faanui
# Processing Record 42 of Set 6 | samarai
# Processing Record 43 of Set 6 | lancut
# Processing Record 44 of Set 6 | saint george
# Processing Record 45 of Set 6 | ghanzi
# Processing Record 46 of Set 6 | batang berjuntai
# Processing Record 47 of Set 6 | tuktoyaktuk
# Processing Record 48 of Set 6 | hendijan
# City not found. Skipping...
# Processing Record 49 of Set 6 | port hueneme
# Processing Record 50 of Set 6 | verkhoyansk
# Processing Record 1 of Set 7 | banjar
# Processing Record 2 of Set 7 | polson
# Processing Record 3 of Set 7 | abu kamal
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | vanimo
# Processing Record 6 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 7 | ornskoldsvik
# Processing Record 8 of Set 7 | tsumeb
# Processing Record 9 of Set 7 | the valley
# Processing Record 10 of Set 7 | grand-lahou
# Processing Record 11 of Set 7 | moron
# Processing Record 12 of Set 7 | cidreira
# Processing Record 13 of Set 7 | rio de janeiro
# Processing Record 14 of Set 7 | waverley
# Processing Record 15 of Set 7 | north bend
# Processing Record 16 of Set 7 | valparai
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | hammerfest
# Processing Record 19 of Set 7 | humaita
# Processing Record 20 of Set 7 | sambava
# Processing Record 21 of Set 7 | minggang
# Processing Record 22 of Set 7 | road town
# Processing Record 23 of Set 7 | rudbar
# Processing Record 24 of Set 7 | neiafu
# Processing Record 25 of Set 7 | cherskiy
# Processing Record 26 of Set 7 | tautira
# Processing Record 27 of Set 7 | petrozavodsk
# Processing Record 28 of Set 7 | qaqortoq
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | port lincoln
# Processing Record 31 of Set 7 | anloga
# Processing Record 32 of Set 7 | mountain home
# Processing Record 33 of Set 7 | springfield
# Processing Record 34 of Set 7 | dudinka
# Processing Record 35 of Set 7 | sabang
# Processing Record 36 of Set 7 | sistranda
# Processing Record 37 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 38 of Set 7 | puerto varas
# Processing Record 39 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 40 of Set 7 | monroe
# Processing Record 41 of Set 7 | doha
# Processing Record 42 of Set 7 | nalut
# Processing Record 43 of Set 7 | sakhon nakhon
# Processing Record 44 of Set 7 | sapa
# Processing Record 45 of Set 7 | beloha
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | sulangan
# Processing Record 48 of Set 7 | pochutla
# Processing Record 49 of Set 7 | pokosnoye
# Processing Record 50 of Set 7 | soyo
# Processing Record 1 of Set 8 | chara
# Processing Record 2 of Set 8 | souillac
# Processing Record 3 of Set 8 | celestun
# Processing Record 4 of Set 8 | sibolga
# Processing Record 5 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 6 of Set 8 | huarmey
# Processing Record 7 of Set 8 | melur
# Processing Record 8 of Set 8 | udachnyy
# Processing Record 9 of Set 8 | afgoye
# City not found. Skipping...
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | cumberland
# Processing Record 12 of Set 8 | ngunguru
# Processing Record 13 of Set 8 | tondon
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | castelo branco
# Processing Record 16 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 17 of Set 8 | conde
# Processing Record 18 of Set 8 | coquimbo
# Processing Record 19 of Set 8 | holme
# Processing Record 20 of Set 8 | brigham city
# Processing Record 21 of Set 8 | qasigiannguit
# Processing Record 22 of Set 8 | werda
# Processing Record 23 of Set 8 | sobolevo
# Processing Record 24 of Set 8 | los llanos de aridane
# Processing Record 25 of Set 8 | toora-khem
# Processing Record 26 of Set 8 | yabrud
# Processing Record 27 of Set 8 | makakilo city
# Processing Record 28 of Set 8 | akyab
# Processing Record 29 of Set 8 | karatau
# Processing Record 30 of Set 8 | quatre cocos
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | yagodnoye
# Processing Record 34 of Set 8 | pozo colorado
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | kuryk
# Processing Record 37 of Set 8 | sorland
# Processing Record 38 of Set 8 | hithadhoo
# Processing Record 39 of Set 8 | calbuco
# Processing Record 40 of Set 8 | safaga
# Processing Record 41 of Set 8 | eyl
# Processing Record 42 of Set 8 | gondanglegi
# Processing Record 43 of Set 8 | buala
# Processing Record 44 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 45 of Set 8 | kentau
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | port macquarie
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | zyryanka
# Processing Record 50 of Set 8 | santa rosa
# Processing Record 1 of Set 9 | chicama
# Processing Record 2 of Set 9 | bubaque
# Processing Record 3 of Set 9 | baft
# Processing Record 4 of Set 9 | muana
# Processing Record 5 of Set 9 | staryy nadym
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | durazno
# Processing Record 8 of Set 9 | andarab
# City not found. Skipping...
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | oum hadjer
# Processing Record 11 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 9 | srednekolymsk
# Processing Record 13 of Set 9 | karabash
# Processing Record 14 of Set 9 | manavalakurichi
# Processing Record 15 of Set 9 | shache
# Processing Record 16 of Set 9 | hami
# Processing Record 17 of Set 9 | asyut
# Processing Record 18 of Set 9 | coihaique
# Processing Record 19 of Set 9 | alekseyevsk
# Processing Record 20 of Set 9 | metu
# Processing Record 21 of Set 9 | cedar city
# Processing Record 22 of Set 9 | alcantara
# Processing Record 23 of Set 9 | usvyaty
# Processing Record 24 of Set 9 | zhigansk
# Processing Record 25 of Set 9 | guerrero negro
# Processing Record 26 of Set 9 | betioky
# Processing Record 27 of Set 9 | tosya
# Processing Record 28 of Set 9 | khammam
# Processing Record 29 of Set 9 | sfantu gheorghe
# Processing Record 30 of Set 9 | urucurituba
# Processing Record 31 of Set 9 | wamba
# Processing Record 32 of Set 9 | seoul
# Processing Record 33 of Set 9 | antalaha
# Processing Record 34 of Set 9 | san quintin
# Processing Record 35 of Set 9 | jambi
# Processing Record 36 of Set 9 | susanville
# Processing Record 37 of Set 9 | tabas
# Processing Record 38 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 9 | iracoubo
# Processing Record 40 of Set 9 | dorado
# Processing Record 41 of Set 9 | puerto quijarro
# Processing Record 42 of Set 9 | olinda
# Processing Record 43 of Set 9 | saint-augustin
# Processing Record 44 of Set 9 | sao filipe
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | miri
# Processing Record 47 of Set 9 | zelenoborskiy
# Processing Record 48 of Set 9 | antropovo
# Processing Record 49 of Set 9 | alice springs
# Processing Record 50 of Set 9 | evensk
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | el cope
# Processing Record 3 of Set 10 | karpathos
# Processing Record 4 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 10 | sumbe
# Processing Record 6 of Set 10 | virginia beach
# Processing Record 7 of Set 10 | jaciara
# Processing Record 8 of Set 10 | marawi
# Processing Record 9 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 10 | sangar
# Processing Record 11 of Set 10 | swan river
# Processing Record 12 of Set 10 | englewood
# Processing Record 13 of Set 10 | nganjuk
# Processing Record 14 of Set 10 | waiouru
# Processing Record 15 of Set 10 | juneau
# Processing Record 16 of Set 10 | gunnedah
# Processing Record 17 of Set 10 | port hardy
# Processing Record 18 of Set 10 | hamilton
# Processing Record 19 of Set 10 | caraballeda
# Processing Record 20 of Set 10 | tocopilla
# Processing Record 21 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 22 of Set 10 | phalia
# Processing Record 23 of Set 10 | bandarbeyla
# Processing Record 24 of Set 10 | saint petersburg
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | yerbogachen
# Processing Record 27 of Set 10 | bambous virieux
# Processing Record 28 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 10 | campoverde
# Processing Record 30 of Set 10 | mareeba
# Processing Record 31 of Set 10 | itarema
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | amga
# Processing Record 35 of Set 10 | nara
# Processing Record 36 of Set 10 | teruel
# Processing Record 37 of Set 10 | kuusamo
# Processing Record 38 of Set 10 | qinhuangdao
# Processing Record 39 of Set 10 | menongue
# Processing Record 40 of Set 10 | naron
# Processing Record 41 of Set 10 | kalawit
# Processing Record 42 of Set 10 | martin
# Processing Record 43 of Set 10 | parichha
# Processing Record 44 of Set 10 | ust-kuyga
# Processing Record 45 of Set 10 | raudeberg
# Processing Record 46 of Set 10 | mecca
# Processing Record 47 of Set 10 | chapais
# Processing Record 48 of Set 10 | suntar
# Processing Record 49 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 50 of Set 10 | achkhoy-martan
# Processing Record 1 of Set 11 | zatoka
# Processing Record 2 of Set 11 | tarancon
# Processing Record 3 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 4 of Set 11 | dauriya
# Processing Record 5 of Set 11 | cururupu
# Processing Record 6 of Set 11 | datong
# Processing Record 7 of Set 11 | manyana
# Processing Record 8 of Set 11 | bani
# Processing Record 9 of Set 11 | santiago de cuba
# Processing Record 10 of Set 11 | port hawkesbury
# Processing Record 11 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 11 | palmer
# Processing Record 13 of Set 11 | churapcha
# Processing Record 14 of Set 11 | wukari
# Processing Record 15 of Set 11 | luderitz
# Processing Record 16 of Set 11 | babu
# Processing Record 17 of Set 11 | senanga
# Processing Record 18 of Set 11 | burica
# City not found. Skipping...
# Processing Record 19 of Set 11 | yashalta
# Processing Record 20 of Set 11 | domanivka
# Processing Record 21 of Set 11 | broome
# Processing Record 22 of Set 11 | mataram
# Processing Record 23 of Set 11 | charters towers
# Processing Record 24 of Set 11 | horsham
# Processing Record 25 of Set 11 | state college
# Processing Record 26 of Set 11 | posta calnau
# Processing Record 27 of Set 11 | arman
# Processing Record 28 of Set 11 | bathsheba
# Processing Record 29 of Set 11 | simao
# Processing Record 30 of Set 11 | bronnoysund
# Processing Record 31 of Set 11 | santa isabel do rio negro
# Processing Record 32 of Set 11 | pokhara
# Processing Record 33 of Set 11 | aksarka
# Processing Record 34 of Set 11 | boa esperanca
# Processing Record 35 of Set 11 | daru
# Processing Record 36 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 11 | bristol
# Processing Record 38 of Set 11 | ler
# Processing Record 39 of Set 11 | anadyr
# Processing Record 40 of Set 11 | mme
# City not found. Skipping...
# Processing Record 41 of Set 11 | tornio
# Processing Record 42 of Set 11 | sal rei
# Processing Record 43 of Set 11 | salto
# Processing Record 44 of Set 11 | kiunga
# Processing Record 45 of Set 11 | odweyne
# Processing Record 46 of Set 11 | riverton
# Processing Record 47 of Set 11 | am timan
# Processing Record 48 of Set 11 | gawler
# Processing Record 49 of Set 11 | otradnyy
# Processing Record 50 of Set 11 | pasni
# Processing Record 1 of Set 12 | vanavara
# Processing Record 2 of Set 12 | garden city
# Processing Record 3 of Set 12 | stykkisholmur
# Processing Record 4 of Set 12 | batagay
# Processing Record 5 of Set 12 | vostok
# Processing Record 6 of Set 12 | waingapu
# Processing Record 7 of Set 12 | nouakchott
# Processing Record 8 of Set 12 | orumiyeh
# Processing Record 9 of Set 12 | okhotsk
# Processing Record 10 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 12 | rongcheng
# Processing Record 12 of Set 12 | iwanai
# Processing Record 13 of Set 12 | pampa
# Processing Record 14 of Set 12 | kijang
# Processing Record 15 of Set 12 | tiarei
# Processing Record 16 of Set 12 | kahului
# Processing Record 17 of Set 12 | bethel
# Processing Record 18 of Set 12 | saint-pierre
# Processing Record 19 of Set 12 | mianyang
# Processing Record 20 of Set 12 | alma
# Processing Record 21 of Set 12 | mezhdurechensk
# Processing Record 22 of Set 12 | bilma
# Processing Record 23 of Set 12 | mapiri
# Processing Record 24 of Set 12 | creel
# Processing Record 25 of Set 12 | acapulco
# Processing Record 26 of Set 12 | kuching
# Processing Record 27 of Set 12 | myitkyina
# Processing Record 28 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 29 of Set 12 | catamarca
# Processing Record 30 of Set 12 | ebeltoft
# Processing Record 31 of Set 12 | broken hill
# Processing Record 32 of Set 12 | deming
# Processing Record 33 of Set 12 | sandusky
# Processing Record 34 of Set 12 | darasun
# Processing Record 35 of Set 12 | lensk
# Processing Record 36 of Set 12 | la sarre
# Processing Record 37 of Set 12 | manaure
# Processing Record 38 of Set 12 | gayeri
# Processing Record 39 of Set 12 | mnogovershinnyy
# Processing Record 40 of Set 12 | ugoofaaru
# Processing Record 41 of Set 12 | mvangue
# Processing Record 42 of Set 12 | praia
# Processing Record 43 of Set 12 | jiuquan
# Processing Record 44 of Set 12 | viamao
# Processing Record 45 of Set 12 | meulaboh
# Processing Record 46 of Set 12 | socorro
# Processing Record 47 of Set 12 | katobu
# Processing Record 48 of Set 12 | hurghada
# Processing Record 49 of Set 12 | bongandanga
# Processing Record 50 of Set 12 | kungurtug
# Processing Record 1 of Set 13 | verkhnevilyuysk
# Processing Record 2 of Set 13 | orlik
# Processing Record 3 of Set 13 | haikou
# Processing Record 4 of Set 13 | gornyy
# Processing Record 5 of Set 13 | mahanoro
# Processing Record 6 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 13 | morro da fumaca
# Processing Record 8 of Set 13 | yulara
# Processing Record 9 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 13 | westport
# Processing Record 11 of Set 13 | naze
# Processing Record 12 of Set 13 | constitucion
# Processing Record 13 of Set 13 | tezu
# Processing Record 14 of Set 13 | mitsamiouli
# Processing Record 15 of Set 13 | orlovskiy
# Processing Record 16 of Set 13 | snasa
# Processing Record 17 of Set 13 | ahuimanu
# Processing Record 18 of Set 13 | warrington
# Processing Record 19 of Set 13 | barkhan
# Processing Record 20 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 13 | bull savanna
# Processing Record 22 of Set 13 | hidalgotitlan
# Processing Record 23 of Set 13 | erdenet
# Processing Record 24 of Set 13 | conakry
# Processing Record 25 of Set 13 | bangassou
# Processing Record 26 of Set 13 | mahibadhoo
# Processing Record 27 of Set 13 | solnechnyy
# Processing Record 28 of Set 13 | ouadda
# Processing Record 29 of Set 13 | ulcinj
# Processing Record 30 of Set 13 | zhob
# Processing Record 31 of Set 13 | san roque
# Processing Record 32 of Set 13 | noyabrsk
# Processing Record 33 of Set 13 | auki
# Processing Record 34 of Set 13 | riberalta
# Processing Record 35 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 13 | lehola
# Processing Record 37 of Set 13 | presidente medici
# Processing Record 38 of Set 13 | new richmond
# Processing Record 39 of Set 13 | portales
# Processing Record 40 of Set 13 | kerema
# Processing Record 41 of Set 13 | aparecida
# Processing Record 42 of Set 13 | eureka
# Processing Record 43 of Set 13 | bima
# Processing Record 44 of Set 13 | kloulklubed
# Processing Record 45 of Set 13 | nanning
# Processing Record 46 of Set 13 | hobyo
# Processing Record 47 of Set 13 | mandali
# Processing Record 48 of Set 13 | valdivia
# Processing Record 49 of Set 13 | catemaco
# Processing Record 50 of Set 13 | awbari
# Processing Record 1 of Set 14 | grand-santi
# Processing Record 2 of Set 14 | nichinan
# Processing Record 3 of Set 14 | mildura
# Processing Record 4 of Set 14 | rawson
# Processing Record 5 of Set 14 | banda aceh
# Processing Record 6 of Set 14 | araouane
# Processing Record 7 of Set 14 | ialibu
# Processing Record 8 of Set 14 | torrijos
# Processing Record 9 of Set 14 | hualmay
# Processing Record 10 of Set 14 | tecolutla
# Processing Record 11 of Set 14 | huilong
# Processing Record 12 of Set 14 | esna
# Processing Record 13 of Set 14 | chiplun
# Processing Record 14 of Set 14 | woodward
# Processing Record 15 of Set 14 | bohuslav
# Processing Record 16 of Set 14 | eydhafushi
# Processing Record 17 of Set 14 | narok
# Processing Record 18 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 14 | santa maria
# Processing Record 20 of Set 14 | olafsvik
# Processing Record 21 of Set 14 | rocha
# Processing Record 22 of Set 14 | opunake
# Processing Record 23 of Set 14 | campbell river
# Processing Record 24 of Set 14 | jumla
# Processing Record 25 of Set 14 | xuchang
# Processing Record 26 of Set 14 | mana
# Processing Record 27 of Set 14 | shahreza
# Processing Record 28 of Set 14 | rochegda
# Processing Record 29 of Set 14 | letlhakane
# Processing Record 30 of Set 14 | pervomayskoye
# Processing Record 31 of Set 14 | malakal
# Processing Record 32 of Set 14 | jacareacanga
# Processing Record 33 of Set 14 | slave lake
# Processing Record 34 of Set 14 | carutapera
# Processing Record 35 of Set 14 | kameoka
# Processing Record 36 of Set 14 | bezhta
# Processing Record 37 of Set 14 | bairiki
# Processing Record 38 of Set 14 | reguengos de monsaraz
# Processing Record 39 of Set 14 | ukiah
# Processing Record 40 of Set 14 | fukue
# Processing Record 41 of Set 14 | oranjemund
# Processing Record 42 of Set 14 | bolshaya atnya
# City not found. Skipping...
# Processing Record 43 of Set 14 | farmington
# Processing Record 44 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 14 | pilot butte
# Processing Record 46 of Set 14 | khani
# Processing Record 47 of Set 14 | madang
# Processing Record 48 of Set 14 | atlantic beach
# Processing Record 49 of Set 14 | monzon
# Processing Record 50 of Set 14 | turukhansk
# Processing Record 1 of Set 15 | morondava
# Processing Record 2 of Set 15 | ous
# Processing Record 3 of Set 15 | booue
# Processing Record 4 of Set 15 | nombre de dios
# Processing Record 5 of Set 15 | ilula
# Processing Record 6 of Set 15 | acarau
# Processing Record 7 of Set 15 | witham
# Processing Record 8 of Set 15 | haileybury
# Processing Record 9 of Set 15 | yarada
# Processing Record 10 of Set 15 | bagli
# Processing Record 11 of Set 15 | valparaiso
# Processing Record 12 of Set 15 | berdigestyakh
# Processing Record 13 of Set 15 | ilinskiy
# Processing Record 14 of Set 15 | san jose
# Processing Record 15 of Set 15 | chimbote
# Processing Record 16 of Set 15 | bosaso
# Processing Record 17 of Set 15 | garowe
# Processing Record 18 of Set 15 | san rafael
# Processing Record 19 of Set 15 | saint-joseph
# Processing Record 20 of Set 15 | poso
# Processing Record 21 of Set 15 | laguna
# Processing Record 22 of Set 15 | bose
# Processing Record 23 of Set 15 | bucine
# Processing Record 24 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 15 | kangly
# Processing Record 26 of Set 15 | ucluelet
# Processing Record 27 of Set 15 | sawakin
# Processing Record 28 of Set 15 | chany
# Processing Record 29 of Set 15 | praya
# Processing Record 30 of Set 15 | spearfish
# Processing Record 31 of Set 15 | hoquiam
# Processing Record 32 of Set 15 | soe
# Processing Record 33 of Set 15 | greytown
# Processing Record 34 of Set 15 | tambura
# Processing Record 35 of Set 15 | assare
# Processing Record 36 of Set 15 | labuan
# Processing Record 37 of Set 15 | urbano santos
# Processing Record 38 of Set 15 | toul
# Processing Record 39 of Set 15 | hirara
# Processing Record 40 of Set 15 | camacha
# Processing Record 41 of Set 15 | port hedland
# Processing Record 42 of Set 15 | vredendal
# Processing Record 43 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 15 | kiama
# Processing Record 45 of Set 15 | esil
# Processing Record 46 of Set 15 | jaisalmer
# Processing Record 47 of Set 15 | tokur
# Processing Record 48 of Set 15 | talakan
# Processing Record 49 of Set 15 | ganzhou
# Processing Record 50 of Set 15 | bay roberts
# Processing Record 1 of Set 16 | picota
# Processing Record 2 of Set 16 | beira
# Processing Record 3 of Set 16 | grand forks
# Processing Record 4 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 16 | manzanillo
# Processing Record 6 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 16 | pisco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally number of cities
len(city_data)
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     49.66        46          20
# 1    Punta Arenas -53.1500  -70.9167     48.31        71          20
# 2          Avarua -21.2078 -159.7750     80.53        74         100
# 3          Hobart -42.8794  147.3294     53.46        82          75
# 4            Lasa  46.6166   10.7002     50.36        95         100
# 5         Aljezur  37.3191   -8.8033     59.40        81          14
# 6          Albany  42.6001  -73.9662     58.46        33         100
# 7       Carnarvon -24.8667  113.6333     62.67        82          75
# 8         Te Anau -45.4167  167.7167     57.00        96         100
# 9  Saint-Philippe -21.3585   55.7679     72.99        83          33
#
#    Wind Speed Weather Description Country                 Date
# 0       21.85          few clouds      AR  2022-05-07 21:59:35
# 1       23.02          few clouds      CL  2022-05-07 21:59:36
# 2        5.30     overcast clouds      CK  2022-05-07 21:59:36
# 3       12.66       broken clouds      AU  2022-05-07 21:58:07
# 4        2.75     overcast clouds      IT  2022-05-07 21:59:37
# 5        6.55          few clouds      PT  2022-05-07 21:59:38
# 6        9.62     overcast clouds      US  2022-05-07 21:59:38
# 7        5.75       broken clouds      AU  2022-05-07 21:56:19
# 8        2.24     overcast clouds      NZ  2022-05-07 21:59:39
# 9       10.87          light rain      RE  2022-05-07 21:53:11

# %%
new_column_order = ['City', 'Country', 'Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Weather Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Ushuaia      AR  2022-05-07 21:59:35 -54.8000  -68.3000     49.66
# 1  Punta Arenas      CL  2022-05-07 21:59:36 -53.1500  -70.9167     48.31
# 2        Avarua      CK  2022-05-07 21:59:36 -21.2078 -159.7750     80.53
# 3        Hobart      AU  2022-05-07 21:58:07 -42.8794  147.3294     53.46
# 4          Lasa      IT  2022-05-07 21:59:37  46.6166   10.7002     50.36
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        46          20       21.85          few clouds
# 1        71          20       23.02          few clouds
# 2        74         100        5.30     overcast clouds
# 3        82          75       12.66       broken clouds
# 4        95         100        2.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = 'Weather_Database/cities.csv'

# Export city_data into CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
